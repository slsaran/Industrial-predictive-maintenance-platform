# %%
from pathlib import Path
import sys

project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.data.load_data import (
    load_ai4i_dataset
)

from src.features.feature_engineering import (
    create_engineered_features
)

from src.features.preprocessing import (
    prepare_modeling_dataset
)

# %%
df = load_ai4i_dataset()

df = create_engineered_features(df)

df = prepare_modeling_dataset(df)

df.head()
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
# 3                298.2                    308.6                    1433
# 4                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Machine failure  Temperature Difference  \
# 0         42.8                0                0                    10.5
# 1         46.3                3                0                    10.5
# 2         49.4                5                0                    10.4
# 3         39.5                7                0                    10.4
# 4         40.0                9                0                    10.5
#
#    Power Proxy  Mechanical Stress Index  Thermal Stress Index  Type_H  Type_L  \
# ...

# %%
df.columns.tolist()
# Out:
# ['Air temperature [K]',
#  'Process temperature [K]',
#  'Rotational speed [rpm]',
#  'Torque [Nm]',
#  'Tool wear [min]',
#  'Machine failure',
#  'Temperature Difference',
#  'Power Proxy',
#  'Mechanical Stress Index',
#  'Thermal Stress Index',
#  'Type_H',
#  'Type_L',
#  'Type_M']

# %%
X = df.drop(
    columns=["Machine failure"]
)

y = df["Machine failure"]

# %%
print("Feature Matrix Shape:", X.shape)

print("Target Shape:", y.shape)
# Out:
# Feature Matrix Shape: (10000, 12)
# Target Shape: (10000,)

# %%
y.value_counts()
# Out:
# Machine failure
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
(
    y.value_counts(
        normalize=True
    ) * 100
).round(2)
# Out:
# Machine failure
# 0    96.61
# 1     3.39
# Name: proportion, dtype: float64

# %%
X.head()
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
# 3                298.2                    308.6                    1433
# 4                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Temperature Difference  Power Proxy  \
# 0         42.8                0                    10.5      66382.8
# 1         46.3                3                    10.5      65190.4
# 2         49.4                5                    10.4      74001.2
# 3         39.5                7                    10.4      56603.5
# 4         40.0                9                    10.5      56320.0
#
#    Mechanical Stress Index  Thermal Stress Index  Type_H  Type_L  Type_M
# ...

# %%
X.columns.tolist()
# Out:
# ['Air temperature [K]',
#  'Process temperature [K]',
#  'Rotational speed [rpm]',
#  'Torque [Nm]',
#  'Tool wear [min]',
#  'Temperature Difference',
#  'Power Proxy',
#  'Mechanical Stress Index',
#  'Thermal Stress Index',
#  'Type_H',
#  'Type_L',
#  'Type_M']

# %% [markdown]
# Modeling Dataset Summary
#
# 1. Identifier columns removed.
#
# 2. Failure-type columns removed to prevent target leakage.
#
# 3. Machine type encoded using one-hot encoding.
#
# 4. Engineered features retained.
#
# 5. Dataset prepared for model training.
#
# 6. Severe class imbalance (~3.4% failures) confirmed.
